# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
# 1.Problemin Çözümünü Buraya Yazınız
def sonhiz(vi,a,t):
     vf=vi+a*t
     print(vf)
sonhiz(5,2,10)
# Out:
# 25

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
# 2.Problemin Çözümünü Buraya Yazınız
def mukemmel_sayi(x):
    a=0
    for i in range(1,x):
        if x%i ==0:
            a=a+i
    if a ==x:
        print(f"{x} mükemmel sayıdır")
    else:
        print(f"{x} mükemmel sayı değildir")

mukemmel_sayi(6)
# Out:
# 6 mükemmel sayıdır

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
# 3.Problemin Çözümünü Buraya Yazınız
import math
def pisagor():
    for a in range(1,101):
        for b in range(a+1,101):
            c_square = a**2+b**2
            c=int(math.sqrt(c_square))
          
            if c<=100 and c**2 == c_square:
             print(f"{a},{b} and {c} is pisagor triangle")

        
pisagor()
# Out:
# 3,4 and 5 is pisagor triangle
# 5,12 and 13 is pisagor triangle
# 6,8 and 10 is pisagor triangle
# 7,24 and 25 is pisagor triangle
# 8,15 and 17 is pisagor triangle
# 9,12 and 15 is pisagor triangle
# 9,40 and 41 is pisagor triangle
# 10,24 and 26 is pisagor triangle
# 11,60 and 61 is pisagor triangle
# 12,16 and 20 is pisagor triangle
# 12,35 and 37 is pisagor triangle
# 13,84 and 85 is pisagor triangle
# 14,48 and 50 is pisagor triangle
# 15,20 and 25 is pisagor triangle
# 15,36 and 39 is pisagor triangle
# 16,30 and 34 is pisagor triangle
# 16,63 and 65 is pisagor triangle
# 18,24 and 30 is pisagor triangle
# 18,80 and 82 is pisagor triangle
# 20,21 and 29 is pisagor triangle
# 20,48 and 52 is pisagor triangle
# 21,28 and 35 is pisagor triangle
# 21,72 and 75 is pisagor triangle
# 24,32 and 40 is pisagor triangle
# 24,45 and 51 is pisagor triangle
# 24,70 and 74 is pisagor triangle
# 25,60 and 65 is pisagor triangle
# 27,36 and 45 is pisagor triangle
# 28,45 and 53 is pisagor triangle
# 28,96 and 100 is pisagor triangle
# 30,40 and 50 is pisagor triangle
# 30,72 and 78 is pisagor triangle
# 32,60 and 68 is pisagor triangle
# 33,44 and 55 is pisagor triangle
# 33,56 and 65 is pisagor triangle
# 35,84 and 91 is pisagor triangle
# 36,48 and 60 is pisagor triangle
# 36,77 and 85 is pisagor triangle
# 39,52 and 65 is pisagor triangle
# 39,80 and 89 is pisagor triangle
# 40,42 and 58 is pisagor triangle
# 40,75 and 85 is pisagor triangle
# 42,56 and 70 is pisagor triangle
# 45,60 and 75 is pisagor triangle
# 48,55 and 73 is pisagor triangle
# 48,64 and 80 is pisagor triangle
# 51,68 and 85 is pisagor triangle
# 54,72 and 90 is pisagor triangle
# 57,76 and 95 is pisagor triangle
# 60,63 and 87 is pisagor triangle
# 60,80 and 100 is pisagor triangle
# 65,72 and 97 is pisagor triangle

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
# 4.Problemin Çözümünü Buraya Yazınız
def kac_kutu(h,w):
    x=h*w/5
    x=round(x)
    print(x)
kac_kutu(2,8)
# Out:
# 3

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
# 5.Problemin Çözümünü Buraya Yazınız
def unsuz_unlu():
    s = input("Kelime: ")
    unlu = ['a', 'e', 'ı', 'i', 'o', 'ö', 'u', 'ü', 'A', 'E', 'I', 'İ', 'O', 'Ö', 'U', 'Ü']
    
    unlu_sayisi = 0
    unsuz_sayisi = 0
    
    for char in s:  
        if char in unlu:
            unlu_sayisi += 1
        else:
            unsuz_sayisi += 1
    
    print(f"Ünlü harf sayısı: {unlu_sayisi}")
    print(f"Ünsüz harf sayısı: {unsuz_sayisi}")

unsuz_unlu()
# Out:
# Ünlü harf sayısı: 3
# Ünsüz harf sayısı: 3

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
# 6.Problemin Çözümünü Buraya Yazınız
def cift_sayi(*x):
    for number in x:
        if number %2 ==0:
            print(number)

cift_sayi(1,2,3,4,5,6,7,8,9)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
# 7.Problemin Çözümünü Buraya Yazınız
def toplam(a):
    if a >10:
        return 0
    else:
        return a + toplam(a + 1)
result= toplam(0)
print(result)
# Out:
# 55

# %%
def hello(name='world'):
    print("hello",name)

hello('ayça')
# Out:
# hello ayça

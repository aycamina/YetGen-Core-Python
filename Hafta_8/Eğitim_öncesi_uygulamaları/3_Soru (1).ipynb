# %% [markdown]
# # Problem 3
#
# Çeşitli metin dosyalarından karakterleri ayıklamak ve bir listeye koymak için bir Python programı yazın. ```test.txt``` ve ```demo.txt``` dosyalarından faydalanabilirsiniz.

# %%
#Sorunun Çözmünü Buraya Gerçekleştirebilirsiniz
characters = []
def read_characters_from_file(filename):
    with open(filename, 'r+', encoding='utf-8') as file:
        content = file.read()
        for char in content:
            if char !='\n':
                characters.append(char)
        print(characters)
read_characters_from_file('test.txt')
read_characters_from_file('demo.txt')
# Out:
# ['a', 'y', 'ç', 'a', 's', 'u', 'b', 'a', 't', 'u', 'h', 'a', 'n', 'e', 'l', 'i', 'f', 'm', 'e', 'l', 'i', 's', 'a', '1', '5', '+', '*']
# ['a', 'y', 'ç', 'a', 's', 'u', 'b', 'a', 't', 'u', 'h', 'a', 'n', 'e', 'l', 'i', 'f', 'm', 'e', 'l', 'i', 's', 'a', '1', '5', '+', '*', 'a', 'k', 'k', 'a', 'v', 'a', 'k', 't', 'a', 'ş', 'd', 'e', 'l', 'e', 'n', 'ö', 'z', 't', 'o', 's', 'u', 'n', 'ö', 'z', 'u', 'b', 'e', 'r', 'k', '4', '5', '5', '6', 'b']
